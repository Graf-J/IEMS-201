# %%
import pandas as pd

# %%
df = pd.read_excel("raw-data.xlsx", header=1)
df
# Out:
#        Team  Student Number Weight Range Year Range    Student Name  \
# 0    Example        Example    3500-4500  2009-2015          Prof A
# 1          1      Student 1    1500-2000  1988-1992  Jack McCartney
# 2          1      Student 1    1500-2000  1988-1992  Jack McCartney
# 3          1      Student 1    1500-2000  1988-1992  Jack McCartney
# 4          1      Student 1    1500-2000  1988-1992  Jack McCartney
# ..       ...            ...          ...        ...             ...
# 621       25      Student 5    3500-4500  2009-2015      Alex Bloom
# 622       25      Student 5    3500-4500  2009-2015      Alex Bloom
# 623       25      Student 5    3500-4500  2009-2015      Alex Bloom
# 624       25      Student 5    3500-4500  2009-2015      Alex Bloom
# 625       25      Student 5    3500-4500  2009-2015      Alex Bloom
#
#                   Car Name  Model Year  Combined HWY and City MPG  \
# 0            The Batmobile      2012.0                       60.0
# ...

# %%
df = df.dropna(subset=["Student Name"])
df
# Out:
#        Team  Student Number Weight Range Year Range    Student Name  \
# 0    Example        Example    3500-4500  2009-2015          Prof A
# 1          1      Student 1    1500-2000  1988-1992  Jack McCartney
# 2          1      Student 1    1500-2000  1988-1992  Jack McCartney
# 3          1      Student 1    1500-2000  1988-1992  Jack McCartney
# 4          1      Student 1    1500-2000  1988-1992  Jack McCartney
# ..       ...            ...          ...        ...             ...
# 621       25      Student 5    3500-4500  2009-2015      Alex Bloom
# 622       25      Student 5    3500-4500  2009-2015      Alex Bloom
# 623       25      Student 5    3500-4500  2009-2015      Alex Bloom
# 624       25      Student 5    3500-4500  2009-2015      Alex Bloom
# 625       25      Student 5    3500-4500  2009-2015      Alex Bloom
#
#                   Car Name  Model Year  Combined HWY and City MPG  \
# 0            The Batmobile      2012.0                       60.0
# ...

# %%
df["Weight (lbs)"] = pd.to_numeric(df["Weight (lbs)"].copy())
# df['% Weight distribution in front'] = pd.to_numeric(df['% Weight distribution in front'])
# df['Length'] = pd.to_numeric(df['Length'])
# df['Width'] = pd.to_numeric(df['Width'])
# df['Height'] = pd.to_numeric(df['Height'])
# df['Engine Displacement (L)'] = pd.to_numeric(df['Engine Displacement (L)'])
# df['Transmission (Speeds) Listed as S6 in the "TRANS" column'] = pd.to_numeric(df['Transmission (Speeds) Listed as S6 in the "TRANS" column'])

df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/lib.pyx:2407, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "2754 lbs"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df["Weight (lbs)"] = pd.to_numeric(df["Weight (lbs)"].copy())
#       2 # df['% Weight distribution in front'] = pd.to_numeric(df['% Weight distribution in front'])
#       3 # df['Length'] = pd.to_numeric(df['Length'])
#       4 # df['Width'] = pd.to_numeric(df['Width'])
#       5 # df['Height'] = pd.to_numeric(df['Height'])
#       6 # df['Engine Displacement (L)'] = pd.to_numeric(df['Engine Displacement (L)'])
# ...

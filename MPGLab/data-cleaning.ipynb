# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("raw-data.xlsx", header=1)
df
# Out:
#        Team  Student Number Weight Range Year Range    Student Name  \
# 0    Example        Example    3500-4500  2009-2015          Prof A
# 1          1      Student 1    1500-2000  1988-1992  Jack McCartney
# 2          1      Student 1    1500-2000  1988-1992  Jack McCartney
# 3          1      Student 1    1500-2000  1988-1992  Jack McCartney
# 4          1      Student 1    1500-2000  1988-1992  Jack McCartney
# ..       ...            ...          ...        ...             ...
# 621       25      Student 5    3500-4500  2009-2015      Alex Bloom
# 622       25      Student 5    3500-4500  2009-2015      Alex Bloom
# 623       25      Student 5    3500-4500  2009-2015      Alex Bloom
# 624       25      Student 5    3500-4500  2009-2015      Alex Bloom
# 625       25      Student 5    3500-4500  2009-2015      Alex Bloom
#
#                   Car Name  Model Year  Combined HWY and City MPG  \
# 0            The Batmobile      2012.0                       60.0
# 1         Mazda Miata MX-5      1992.0                       23.0
# 2      Chyrsler New Yorker      1992.0                       19.0
# 3      Ford Crown Victoria      1992.0                       20.0
# 4         Cadillac Seville      1992.0                       18.0
# ..                     ...         ...                        ...
# 621           Ford Mustang      2010.0                       19.0
# 622    Audi Q5 5DR SUV 2.0      2012.0                       22.0
# 623  Maserati Quattroporte      2012.0                       15.0
# 624  Mercedez-Benz CLS 550      2009.0                       23.0
# 625      Toyota FJ Cruiser      2009.0                       26.0
#
#     Weight (lbs) % Weight distribution in front  Length  Width Height  \
# 0           4000                             59  191.73  70.47  57.09
# 1           2121                             53  155.51  66.14  48.03
# 2           3337                             63   193.7   68.9  53.54
# 3           3738                             56   212.6  77.95  56.69
# 4           3557                             63  204.33  74.41  53.94
# ..           ...                            ...     ...    ...    ...
# 621         3750                             53  188.19  74.02  55.91
# 622      4089.57                             53  182.28   74.8  65.35
# 623       4376.5                             47   198.2  74.41  56.69
# 624         3982                             52   193.7  73.62  54.72
# 625         4286                             53  177.17   75.2  72.05
#
#      Cylinders Engine Displacement (L)  \
# 0          8.0                     2.4
# 1          4.0                     1.6
# 2          6.0                     3.3
# 3          8.0                     4.6
# 4          8.0                     4.9
# ..         ...                     ...
# 621        8.0                     4.6
# 622        4.0                       2
# 623        8.0                     4.7
# 624        8.0                     5.5
# 625        4.0                       2
#
#      Transmission Type ("1" for Auto and "0" for Manual)  \
# 0                                                  1.0
# 1                                                  0.0
# 2                                                  1.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 621                                                1.0
# 622                                                1.0
# 623                                                1.0
# 624                                                1.0
# 625                                                1.0
#
#     Transmission (Speeds) Listed as S6 in the "TRANS" column
# 0                                                   15
# 1                                                    5
# 2                                                    4
# 3                                                    4
# 4                                                    4
# ..                                                 ...
# 621                                                  5
# 622                                                  8
# 623                                                  6
# 624                                                  6
# 625                                                  5
#
# [626 rows x 17 columns]

# %% [markdown]
# # Drop empty Rows

# %%
df = df.dropna(subset=["Student Name"])
df
# Out:
#        Team  Student Number Weight Range Year Range    Student Name  \
# 0    Example        Example    3500-4500  2009-2015          Prof A
# 1          1      Student 1    1500-2000  1988-1992  Jack McCartney
# 2          1      Student 1    1500-2000  1988-1992  Jack McCartney
# 3          1      Student 1    1500-2000  1988-1992  Jack McCartney
# 4          1      Student 1    1500-2000  1988-1992  Jack McCartney
# ..       ...            ...          ...        ...             ...
# 621       25      Student 5    3500-4500  2009-2015      Alex Bloom
# 622       25      Student 5    3500-4500  2009-2015      Alex Bloom
# 623       25      Student 5    3500-4500  2009-2015      Alex Bloom
# 624       25      Student 5    3500-4500  2009-2015      Alex Bloom
# 625       25      Student 5    3500-4500  2009-2015      Alex Bloom
#
#                   Car Name  Model Year  Combined HWY and City MPG  \
# 0            The Batmobile      2012.0                       60.0
# 1         Mazda Miata MX-5      1992.0                       23.0
# 2      Chyrsler New Yorker      1992.0                       19.0
# 3      Ford Crown Victoria      1992.0                       20.0
# 4         Cadillac Seville      1992.0                       18.0
# ..                     ...         ...                        ...
# 621           Ford Mustang      2010.0                       19.0
# 622    Audi Q5 5DR SUV 2.0      2012.0                       22.0
# 623  Maserati Quattroporte      2012.0                       15.0
# 624  Mercedez-Benz CLS 550      2009.0                       23.0
# 625      Toyota FJ Cruiser      2009.0                       26.0
#
#     Weight (lbs) % Weight distribution in front  Length  Width Height  \
# 0           4000                             59  191.73  70.47  57.09
# 1           2121                             53  155.51  66.14  48.03
# 2           3337                             63   193.7   68.9  53.54
# 3           3738                             56   212.6  77.95  56.69
# 4           3557                             63  204.33  74.41  53.94
# ..           ...                            ...     ...    ...    ...
# 621         3750                             53  188.19  74.02  55.91
# 622      4089.57                             53  182.28   74.8  65.35
# 623       4376.5                             47   198.2  74.41  56.69
# 624         3982                             52   193.7  73.62  54.72
# 625         4286                             53  177.17   75.2  72.05
#
#      Cylinders Engine Displacement (L)  \
# 0          8.0                     2.4
# 1          4.0                     1.6
# 2          6.0                     3.3
# 3          8.0                     4.6
# 4          8.0                     4.9
# ..         ...                     ...
# 621        8.0                     4.6
# 622        4.0                       2
# 623        8.0                     4.7
# 624        8.0                     5.5
# 625        4.0                       2
#
#      Transmission Type ("1" for Auto and "0" for Manual)  \
# 0                                                  1.0
# 1                                                  0.0
# 2                                                  1.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 621                                                1.0
# 622                                                1.0
# 623                                                1.0
# 624                                                1.0
# 625                                                1.0
#
#     Transmission (Speeds) Listed as S6 in the "TRANS" column
# 0                                                   15
# 1                                                    5
# 2                                                    4
# 3                                                    4
# 4                                                    4
# ..                                                 ...
# 621                                                  5
# 622                                                  8
# 623                                                  6
# 624                                                  6
# 625                                                  5
#
# [512 rows x 17 columns]

# %% [markdown]
# # Convert Columns in correct Datatypes
# ## Team
# * Set Professor's Example to Team 0
# * Convert Column to Numeric Datatype

# %%
df.loc[0, "Team "] = 0
df = df.astype({"Team ": "int8"})
df
# Out:
#      Team  Student Number Weight Range Year Range    Student Name  \
# 0        0        Example    3500-4500  2009-2015          Prof A
# 1        1      Student 1    1500-2000  1988-1992  Jack McCartney
# 2        1      Student 1    1500-2000  1988-1992  Jack McCartney
# 3        1      Student 1    1500-2000  1988-1992  Jack McCartney
# 4        1      Student 1    1500-2000  1988-1992  Jack McCartney
# ..     ...            ...          ...        ...             ...
# 621     25      Student 5    3500-4500  2009-2015      Alex Bloom
# 622     25      Student 5    3500-4500  2009-2015      Alex Bloom
# 623     25      Student 5    3500-4500  2009-2015      Alex Bloom
# 624     25      Student 5    3500-4500  2009-2015      Alex Bloom
# 625     25      Student 5    3500-4500  2009-2015      Alex Bloom
#
#                   Car Name  Model Year  Combined HWY and City MPG  \
# 0            The Batmobile      2012.0                       60.0
# 1         Mazda Miata MX-5      1992.0                       23.0
# 2      Chyrsler New Yorker      1992.0                       19.0
# 3      Ford Crown Victoria      1992.0                       20.0
# 4         Cadillac Seville      1992.0                       18.0
# ..                     ...         ...                        ...
# 621           Ford Mustang      2010.0                       19.0
# 622    Audi Q5 5DR SUV 2.0      2012.0                       22.0
# 623  Maserati Quattroporte      2012.0                       15.0
# 624  Mercedez-Benz CLS 550      2009.0                       23.0
# 625      Toyota FJ Cruiser      2009.0                       26.0
#
#     Weight (lbs) % Weight distribution in front  Length  Width Height  \
# 0           4000                             59  191.73  70.47  57.09
# 1           2121                             53  155.51  66.14  48.03
# 2           3337                             63   193.7   68.9  53.54
# 3           3738                             56   212.6  77.95  56.69
# 4           3557                             63  204.33  74.41  53.94
# ..           ...                            ...     ...    ...    ...
# 621         3750                             53  188.19  74.02  55.91
# 622      4089.57                             53  182.28   74.8  65.35
# 623       4376.5                             47   198.2  74.41  56.69
# 624         3982                             52   193.7  73.62  54.72
# 625         4286                             53  177.17   75.2  72.05
#
#      Cylinders Engine Displacement (L)  \
# 0          8.0                     2.4
# 1          4.0                     1.6
# 2          6.0                     3.3
# 3          8.0                     4.6
# 4          8.0                     4.9
# ..         ...                     ...
# 621        8.0                     4.6
# 622        4.0                       2
# 623        8.0                     4.7
# 624        8.0                     5.5
# 625        4.0                       2
#
#      Transmission Type ("1" for Auto and "0" for Manual)  \
# 0                                                  1.0
# 1                                                  0.0
# 2                                                  1.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 621                                                1.0
# 622                                                1.0
# 623                                                1.0
# 624                                                1.0
# 625                                                1.0
#
#     Transmission (Speeds) Listed as S6 in the "TRANS" column
# 0                                                   15
# 1                                                    5
# 2                                                    4
# 3                                                    4
# 4                                                    4
# ..                                                 ...
# 621                                                  5
# 622                                                  8
# 623                                                  6
# 624                                                  6
# 625                                                  5
#
# [512 rows x 17 columns]

# %% [markdown]
# ## Studnet Number
# * Set Professor's Student Number to 0
# * Remove "Student" (e.g. Student 3 -> 3)
# * Convert Column to Numeric Datatype

# %%
df.loc[0, "Student Number"] = "Student 0"
df.loc[:, "Student Number"] = df["Student Number"].str.replace("Student ", "")
df = df.astype({"Student Number": "int8"})
df
# Out:
#      Team   Student Number Weight Range Year Range    Student Name  \
# 0        0               0    3500-4500  2009-2015          Prof A
# 1        1               1    1500-2000  1988-1992  Jack McCartney
# 2        1               1    1500-2000  1988-1992  Jack McCartney
# 3        1               1    1500-2000  1988-1992  Jack McCartney
# 4        1               1    1500-2000  1988-1992  Jack McCartney
# ..     ...             ...          ...        ...             ...
# 621     25               5    3500-4500  2009-2015      Alex Bloom
# 622     25               5    3500-4500  2009-2015      Alex Bloom
# 623     25               5    3500-4500  2009-2015      Alex Bloom
# 624     25               5    3500-4500  2009-2015      Alex Bloom
# 625     25               5    3500-4500  2009-2015      Alex Bloom
#
#                   Car Name  Model Year  Combined HWY and City MPG  \
# 0            The Batmobile      2012.0                       60.0
# 1         Mazda Miata MX-5      1992.0                       23.0
# 2      Chyrsler New Yorker      1992.0                       19.0
# 3      Ford Crown Victoria      1992.0                       20.0
# 4         Cadillac Seville      1992.0                       18.0
# ..                     ...         ...                        ...
# 621           Ford Mustang      2010.0                       19.0
# 622    Audi Q5 5DR SUV 2.0      2012.0                       22.0
# 623  Maserati Quattroporte      2012.0                       15.0
# 624  Mercedez-Benz CLS 550      2009.0                       23.0
# 625      Toyota FJ Cruiser      2009.0                       26.0
#
#     Weight (lbs) % Weight distribution in front  Length  Width Height  \
# 0           4000                             59  191.73  70.47  57.09
# 1           2121                             53  155.51  66.14  48.03
# 2           3337                             63   193.7   68.9  53.54
# 3           3738                             56   212.6  77.95  56.69
# 4           3557                             63  204.33  74.41  53.94
# ..           ...                            ...     ...    ...    ...
# 621         3750                             53  188.19  74.02  55.91
# 622      4089.57                             53  182.28   74.8  65.35
# 623       4376.5                             47   198.2  74.41  56.69
# 624         3982                             52   193.7  73.62  54.72
# 625         4286                             53  177.17   75.2  72.05
#
#      Cylinders Engine Displacement (L)  \
# 0          8.0                     2.4
# 1          4.0                     1.6
# 2          6.0                     3.3
# 3          8.0                     4.6
# 4          8.0                     4.9
# ..         ...                     ...
# 621        8.0                     4.6
# 622        4.0                       2
# 623        8.0                     4.7
# 624        8.0                     5.5
# 625        4.0                       2
#
#      Transmission Type ("1" for Auto and "0" for Manual)  \
# 0                                                  1.0
# 1                                                  0.0
# 2                                                  1.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 621                                                1.0
# 622                                                1.0
# 623                                                1.0
# 624                                                1.0
# 625                                                1.0
#
#     Transmission (Speeds) Listed as S6 in the "TRANS" column
# 0                                                   15
# 1                                                    5
# 2                                                    4
# 3                                                    4
# 4                                                    4
# ..                                                 ...
# 621                                                  5
# 622                                                  8
# 623                                                  6
# 624                                                  6
# 625                                                  5
#
# [512 rows x 17 columns]

# %% [markdown]
# ## Weight (lbs)
# * Remove "lbs"
# * Convert Column to Numeric Datatype

# %%
df.loc[:, "Weight (lbs)"] = (
    df["Weight (lbs)"].astype(str).str.replace("lbs", "", regex=False)
)
df = df.astype({"Weight (lbs)": "float32"})
df
# Out:
#      Team   Student Number Weight Range Year Range    Student Name  \
# 0        0               0    3500-4500  2009-2015          Prof A
# 1        1               1    1500-2000  1988-1992  Jack McCartney
# 2        1               1    1500-2000  1988-1992  Jack McCartney
# 3        1               1    1500-2000  1988-1992  Jack McCartney
# 4        1               1    1500-2000  1988-1992  Jack McCartney
# ..     ...             ...          ...        ...             ...
# 621     25               5    3500-4500  2009-2015      Alex Bloom
# 622     25               5    3500-4500  2009-2015      Alex Bloom
# 623     25               5    3500-4500  2009-2015      Alex Bloom
# 624     25               5    3500-4500  2009-2015      Alex Bloom
# 625     25               5    3500-4500  2009-2015      Alex Bloom
#
#                   Car Name  Model Year  Combined HWY and City MPG  \
# 0            The Batmobile      2012.0                       60.0
# 1         Mazda Miata MX-5      1992.0                       23.0
# 2      Chyrsler New Yorker      1992.0                       19.0
# 3      Ford Crown Victoria      1992.0                       20.0
# 4         Cadillac Seville      1992.0                       18.0
# ..                     ...         ...                        ...
# 621           Ford Mustang      2010.0                       19.0
# 622    Audi Q5 5DR SUV 2.0      2012.0                       22.0
# 623  Maserati Quattroporte      2012.0                       15.0
# 624  Mercedez-Benz CLS 550      2009.0                       23.0
# 625      Toyota FJ Cruiser      2009.0                       26.0
#
#      Weight (lbs) % Weight distribution in front  Length  Width Height  \
# 0     4000.000000                             59  191.73  70.47  57.09
# 1     2121.000000                             53  155.51  66.14  48.03
# 2     3337.000000                             63   193.7   68.9  53.54
# 3     3738.000000                             56   212.6  77.95  56.69
# 4     3557.000000                             63  204.33  74.41  53.94
# ..            ...                            ...     ...    ...    ...
# 621   3750.000000                             53  188.19  74.02  55.91
# 622   4089.570068                             53  182.28   74.8  65.35
# 623   4376.500000                             47   198.2  74.41  56.69
# 624   3982.000000                             52   193.7  73.62  54.72
# 625   4286.000000                             53  177.17   75.2  72.05
#
#      Cylinders Engine Displacement (L)  \
# 0          8.0                     2.4
# 1          4.0                     1.6
# 2          6.0                     3.3
# 3          8.0                     4.6
# 4          8.0                     4.9
# ..         ...                     ...
# 621        8.0                     4.6
# 622        4.0                       2
# 623        8.0                     4.7
# 624        8.0                     5.5
# 625        4.0                       2
#
#      Transmission Type ("1" for Auto and "0" for Manual)  \
# 0                                                  1.0
# 1                                                  0.0
# 2                                                  1.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 621                                                1.0
# 622                                                1.0
# 623                                                1.0
# 624                                                1.0
# 625                                                1.0
#
#     Transmission (Speeds) Listed as S6 in the "TRANS" column
# 0                                                   15
# 1                                                    5
# 2                                                    4
# 3                                                    4
# 4                                                    4
# ..                                                 ...
# 621                                                  5
# 622                                                  8
# 623                                                  6
# 624                                                  6
# 625                                                  5
#
# [512 rows x 17 columns]

# %% [markdown]
# ## % Weight distribution in front
# * Remove --, -, None listed, and Not listed from Column
# * Convert fractions (e.g. 60/40 -> 60)
# * Convert Column to Numeric Datatype

# %%
def clean_value(val):
    if str(val).strip() in ["--", "-", "None listed", "Not Listed"]:
        return np.nan

    if isinstance(val, str) and "/" in val:
        numerator = val.split("/")[0]
        return numerator

    return val


df.loc[:, "% Weight distribution in front"] = df[
    "% Weight distribution in front"
].apply(clean_value)
df = df.astype({"% Weight distribution in front": "float32"})
df
# Out:
#      Team   Student Number Weight Range Year Range    Student Name  \
# 0        0               0    3500-4500  2009-2015          Prof A
# 1        1               1    1500-2000  1988-1992  Jack McCartney
# 2        1               1    1500-2000  1988-1992  Jack McCartney
# 3        1               1    1500-2000  1988-1992  Jack McCartney
# 4        1               1    1500-2000  1988-1992  Jack McCartney
# ..     ...             ...          ...        ...             ...
# 621     25               5    3500-4500  2009-2015      Alex Bloom
# 622     25               5    3500-4500  2009-2015      Alex Bloom
# 623     25               5    3500-4500  2009-2015      Alex Bloom
# 624     25               5    3500-4500  2009-2015      Alex Bloom
# 625     25               5    3500-4500  2009-2015      Alex Bloom
#
#                   Car Name  Model Year  Combined HWY and City MPG  \
# 0            The Batmobile      2012.0                       60.0
# 1         Mazda Miata MX-5      1992.0                       23.0
# 2      Chyrsler New Yorker      1992.0                       19.0
# 3      Ford Crown Victoria      1992.0                       20.0
# 4         Cadillac Seville      1992.0                       18.0
# ..                     ...         ...                        ...
# 621           Ford Mustang      2010.0                       19.0
# 622    Audi Q5 5DR SUV 2.0      2012.0                       22.0
# 623  Maserati Quattroporte      2012.0                       15.0
# 624  Mercedez-Benz CLS 550      2009.0                       23.0
# 625      Toyota FJ Cruiser      2009.0                       26.0
#
#      Weight (lbs)  % Weight distribution in front  Length  Width Height  \
# 0     4000.000000                            59.0  191.73  70.47  57.09
# 1     2121.000000                            53.0  155.51  66.14  48.03
# 2     3337.000000                            63.0   193.7   68.9  53.54
# 3     3738.000000                            56.0   212.6  77.95  56.69
# 4     3557.000000                            63.0  204.33  74.41  53.94
# ..            ...                             ...     ...    ...    ...
# 621   3750.000000                            53.0  188.19  74.02  55.91
# 622   4089.570068                            53.0  182.28   74.8  65.35
# 623   4376.500000                            47.0   198.2  74.41  56.69
# 624   3982.000000                            52.0   193.7  73.62  54.72
# 625   4286.000000                            53.0  177.17   75.2  72.05
#
#      Cylinders Engine Displacement (L)  \
# 0          8.0                     2.4
# 1          4.0                     1.6
# 2          6.0                     3.3
# 3          8.0                     4.6
# 4          8.0                     4.9
# ..         ...                     ...
# 621        8.0                     4.6
# 622        4.0                       2
# 623        8.0                     4.7
# 624        8.0                     5.5
# 625        4.0                       2
#
#      Transmission Type ("1" for Auto and "0" for Manual)  \
# 0                                                  1.0
# 1                                                  0.0
# 2                                                  1.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 621                                                1.0
# 622                                                1.0
# 623                                                1.0
# 624                                                1.0
# 625                                                1.0
#
#     Transmission (Speeds) Listed as S6 in the "TRANS" column
# 0                                                   15
# 1                                                    5
# 2                                                    4
# 3                                                    4
# 4                                                    4
# ..                                                 ...
# 621                                                  5
# 622                                                  8
# 623                                                  6
# 624                                                  6
# 625                                                  5
#
# [512 rows x 17 columns]

# %% [markdown]
# ## Length / Width / Height
# * Remove "in"
# * Convert Columns to Numeric Datatype

# %%
df.loc[:, ["Length", "Width", "Height"]] = (
    df[["Length", "Width", "Height"]].astype(str).map(lambda x: x.replace("in", ""))
)
df = df.astype({"Length": "float32", "Width": "float32", "Height": "float32"})
df
# Out:
#      Team   Student Number Weight Range Year Range    Student Name  \
# 0        0               0    3500-4500  2009-2015          Prof A
# 1        1               1    1500-2000  1988-1992  Jack McCartney
# 2        1               1    1500-2000  1988-1992  Jack McCartney
# 3        1               1    1500-2000  1988-1992  Jack McCartney
# 4        1               1    1500-2000  1988-1992  Jack McCartney
# ..     ...             ...          ...        ...             ...
# 621     25               5    3500-4500  2009-2015      Alex Bloom
# 622     25               5    3500-4500  2009-2015      Alex Bloom
# 623     25               5    3500-4500  2009-2015      Alex Bloom
# 624     25               5    3500-4500  2009-2015      Alex Bloom
# 625     25               5    3500-4500  2009-2015      Alex Bloom
#
#                   Car Name  Model Year  Combined HWY and City MPG  \
# 0            The Batmobile      2012.0                       60.0
# 1         Mazda Miata MX-5      1992.0                       23.0
# 2      Chyrsler New Yorker      1992.0                       19.0
# 3      Ford Crown Victoria      1992.0                       20.0
# 4         Cadillac Seville      1992.0                       18.0
# ..                     ...         ...                        ...
# 621           Ford Mustang      2010.0                       19.0
# 622    Audi Q5 5DR SUV 2.0      2012.0                       22.0
# 623  Maserati Quattroporte      2012.0                       15.0
# 624  Mercedez-Benz CLS 550      2009.0                       23.0
# 625      Toyota FJ Cruiser      2009.0                       26.0
#
#      Weight (lbs)  % Weight distribution in front      Length      Width  \
# 0     4000.000000                            59.0  191.729996  70.470001
# 1     2121.000000                            53.0  155.509995  66.139999
# 2     3337.000000                            63.0  193.699997  68.900002
# 3     3738.000000                            56.0  212.600006  77.949997
# 4     3557.000000                            63.0  204.330002  74.410004
# ..            ...                             ...         ...        ...
# 621   3750.000000                            53.0  188.190002  74.019997
# 622   4089.570068                            53.0  182.279999  74.800003
# 623   4376.500000                            47.0  198.199997  74.410004
# 624   3982.000000                            52.0  193.699997  73.620003
# 625   4286.000000                            53.0  177.169998  75.199997
#
#         Height  Cylinders Engine Displacement (L)  \
# 0    57.090000        8.0                     2.4
# 1    48.029999        4.0                     1.6
# 2    53.540001        6.0                     3.3
# 3    56.689999        8.0                     4.6
# 4    53.939999        8.0                     4.9
# ..         ...        ...                     ...
# 621  55.910000        8.0                     4.6
# 622  65.349998        4.0                       2
# 623  56.689999        8.0                     4.7
# 624  54.720001        8.0                     5.5
# 625  72.050003        4.0                       2
#
#      Transmission Type ("1" for Auto and "0" for Manual)  \
# 0                                                  1.0
# 1                                                  0.0
# 2                                                  1.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 621                                                1.0
# 622                                                1.0
# 623                                                1.0
# 624                                                1.0
# 625                                                1.0
#
#     Transmission (Speeds) Listed as S6 in the "TRANS" column
# 0                                                   15
# 1                                                    5
# 2                                                    4
# 3                                                    4
# 4                                                    4
# ..                                                 ...
# 621                                                  5
# 622                                                  8
# 623                                                  6
# 624                                                  6
# 625                                                  5
#
# [512 rows x 17 columns]

# %% [markdown]
# ## Engine Displacement (L)
# * Remove "L"
# * Convert Column to Numeric Datatype

# %%
df.loc[:, "Engine Displacement (L)"] = (
    df["Engine Displacement (L)"].astype(str).str.replace("L", "", regex=False)
)
df = df.astype({"Engine Displacement (L)": "float32"})
df
# Out:
#      Team   Student Number Weight Range Year Range    Student Name  \
# 0        0               0    3500-4500  2009-2015          Prof A
# 1        1               1    1500-2000  1988-1992  Jack McCartney
# 2        1               1    1500-2000  1988-1992  Jack McCartney
# 3        1               1    1500-2000  1988-1992  Jack McCartney
# 4        1               1    1500-2000  1988-1992  Jack McCartney
# ..     ...             ...          ...        ...             ...
# 621     25               5    3500-4500  2009-2015      Alex Bloom
# 622     25               5    3500-4500  2009-2015      Alex Bloom
# 623     25               5    3500-4500  2009-2015      Alex Bloom
# 624     25               5    3500-4500  2009-2015      Alex Bloom
# 625     25               5    3500-4500  2009-2015      Alex Bloom
#
#                   Car Name  Model Year  Combined HWY and City MPG  \
# 0            The Batmobile      2012.0                       60.0
# 1         Mazda Miata MX-5      1992.0                       23.0
# 2      Chyrsler New Yorker      1992.0                       19.0
# 3      Ford Crown Victoria      1992.0                       20.0
# 4         Cadillac Seville      1992.0                       18.0
# ..                     ...         ...                        ...
# 621           Ford Mustang      2010.0                       19.0
# 622    Audi Q5 5DR SUV 2.0      2012.0                       22.0
# 623  Maserati Quattroporte      2012.0                       15.0
# 624  Mercedez-Benz CLS 550      2009.0                       23.0
# 625      Toyota FJ Cruiser      2009.0                       26.0
#
#      Weight (lbs)  % Weight distribution in front      Length      Width  \
# 0     4000.000000                            59.0  191.729996  70.470001
# 1     2121.000000                            53.0  155.509995  66.139999
# 2     3337.000000                            63.0  193.699997  68.900002
# 3     3738.000000                            56.0  212.600006  77.949997
# 4     3557.000000                            63.0  204.330002  74.410004
# ..            ...                             ...         ...        ...
# 621   3750.000000                            53.0  188.190002  74.019997
# 622   4089.570068                            53.0  182.279999  74.800003
# 623   4376.500000                            47.0  198.199997  74.410004
# 624   3982.000000                            52.0  193.699997  73.620003
# 625   4286.000000                            53.0  177.169998  75.199997
#
#         Height  Cylinders  Engine Displacement (L)  \
# 0    57.090000        8.0                      2.4
# 1    48.029999        4.0                      1.6
# 2    53.540001        6.0                      3.3
# 3    56.689999        8.0                      4.6
# 4    53.939999        8.0                      4.9
# ..         ...        ...                      ...
# 621  55.910000        8.0                      4.6
# 622  65.349998        4.0                      2.0
# 623  56.689999        8.0                      4.7
# 624  54.720001        8.0                      5.5
# 625  72.050003        4.0                      2.0
#
#      Transmission Type ("1" for Auto and "0" for Manual)  \
# 0                                                  1.0
# 1                                                  0.0
# 2                                                  1.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 621                                                1.0
# 622                                                1.0
# 623                                                1.0
# 624                                                1.0
# 625                                                1.0
#
#     Transmission (Speeds) Listed as S6 in the "TRANS" column
# 0                                                   15
# 1                                                    5
# 2                                                    4
# 3                                                    4
# 4                                                    4
# ..                                                 ...
# 621                                                  5
# 622                                                  8
# 623                                                  6
# 624                                                  6
# 625                                                  5
#
# [512 rows x 17 columns]

# %% [markdown]
# # Drop Rows
# ## Transmission (Speeds) Listed as S6 in the "TRANS" column
# * Remove transmission type labels (e.g., Manual, Automatic) and only keep gear count number (e.g., Auto(M6) → 6)
# * Keep AV Engines (since I don't know what it is it needs further investigation)

# %%
def clean_data(val):
    if pd.isna(val):
        return np.nan

    if "AV" in str(val):
        return "AV"

    if isinstance(val, (int, float)):
        return val

    digits = [digit for digit in str(val) if str.isdigit(digit)]
    return int(digits[0]) if digits else np.nan


df.loc[:, 'Transmission (Speeds) Listed as S6 in the "TRANS" column'] = df[
    'Transmission (Speeds) Listed as S6 in the "TRANS" column'
].apply(clean_data)
df
# Out:
#      Team   Student Number Weight Range Year Range    Student Name  \
# 0        0               0    3500-4500  2009-2015          Prof A
# 1        1               1    1500-2000  1988-1992  Jack McCartney
# 2        1               1    1500-2000  1988-1992  Jack McCartney
# 3        1               1    1500-2000  1988-1992  Jack McCartney
# 4        1               1    1500-2000  1988-1992  Jack McCartney
# ..     ...             ...          ...        ...             ...
# 621     25               5    3500-4500  2009-2015      Alex Bloom
# 622     25               5    3500-4500  2009-2015      Alex Bloom
# 623     25               5    3500-4500  2009-2015      Alex Bloom
# 624     25               5    3500-4500  2009-2015      Alex Bloom
# 625     25               5    3500-4500  2009-2015      Alex Bloom
#
#                   Car Name  Model Year  Combined HWY and City MPG  \
# 0            The Batmobile      2012.0                       60.0
# 1         Mazda Miata MX-5      1992.0                       23.0
# 2      Chyrsler New Yorker      1992.0                       19.0
# 3      Ford Crown Victoria      1992.0                       20.0
# 4         Cadillac Seville      1992.0                       18.0
# ..                     ...         ...                        ...
# 621           Ford Mustang      2010.0                       19.0
# 622    Audi Q5 5DR SUV 2.0      2012.0                       22.0
# 623  Maserati Quattroporte      2012.0                       15.0
# 624  Mercedez-Benz CLS 550      2009.0                       23.0
# 625      Toyota FJ Cruiser      2009.0                       26.0
#
#      Weight (lbs)  % Weight distribution in front      Length      Width  \
# 0     4000.000000                            59.0  191.729996  70.470001
# 1     2121.000000                            53.0  155.509995  66.139999
# 2     3337.000000                            63.0  193.699997  68.900002
# 3     3738.000000                            56.0  212.600006  77.949997
# 4     3557.000000                            63.0  204.330002  74.410004
# ..            ...                             ...         ...        ...
# 621   3750.000000                            53.0  188.190002  74.019997
# 622   4089.570068                            53.0  182.279999  74.800003
# 623   4376.500000                            47.0  198.199997  74.410004
# 624   3982.000000                            52.0  193.699997  73.620003
# 625   4286.000000                            53.0  177.169998  75.199997
#
#         Height  Cylinders  Engine Displacement (L)  \
# 0    57.090000        8.0                      2.4
# 1    48.029999        4.0                      1.6
# 2    53.540001        6.0                      3.3
# 3    56.689999        8.0                      4.6
# 4    53.939999        8.0                      4.9
# ..         ...        ...                      ...
# 621  55.910000        8.0                      4.6
# 622  65.349998        4.0                      2.0
# 623  56.689999        8.0                      4.7
# 624  54.720001        8.0                      5.5
# 625  72.050003        4.0                      2.0
#
#      Transmission Type ("1" for Auto and "0" for Manual)  \
# 0                                                  1.0
# 1                                                  0.0
# 2                                                  1.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 621                                                1.0
# 622                                                1.0
# 623                                                1.0
# 624                                                1.0
# 625                                                1.0
#
#     Transmission (Speeds) Listed as S6 in the "TRANS" column
# 0                                                   15
# 1                                                    5
# 2                                                    4
# 3                                                    4
# 4                                                    4
# ..                                                 ...
# 621                                                  5
# 622                                                  8
# 623                                                  6
# 624                                                  6
# 625                                                  5
#
# [512 rows x 17 columns]

# %%
av_mask = df['Transmission (Speeds) Listed as S6 in the "TRANS" column'] == "AV"
df_av = df[av_mask].copy()
df_non_av = df[~av_mask].copy()

fig, axs = plt.subplots(nrows=2, ncols=5, figsize=(15, 6))

axs[0, 0].scatter(
    np.where(av_mask == 0)[0],
    df_non_av["Combined HWY and City MPG"],
    color="gray",
    label="Non-AV",
)
axs[0, 0].scatter(
    np.where(av_mask == 1)[0],
    df_av["Combined HWY and City MPG"],
    color="red",
    label="AV",
)
axs[0, 0].set_title("Combined HWY and City MPG")
axs[0, 0].set_xlabel("Index")
axs[0, 0].set_ylabel("Combined HWY and City MPG")
axs[0, 0].legend()

axs[0, 1].scatter(
    np.where(av_mask == 0)[0], df_non_av["Model Year"], color="gray", label="Non-AV"
)
axs[0, 1].scatter(
    np.where(av_mask == 1)[0], df_av["Model Year"], color="red", label="AV"
)
axs[0, 1].set_title("Model Year")
axs[0, 1].set_xlabel("Index")
axs[0, 1].set_ylabel("Model Year")
axs[0, 1].legend()

axs[0, 2].scatter(
    np.where(av_mask == 0)[0],
    df_non_av["Weight (lbs)"],
    color="gray",
    label="Non-AV",
)
axs[0, 2].scatter(
    np.where(av_mask == 1)[0],
    df_av["Weight (lbs)"],
    color="red",
    label="AV",
)
axs[0, 2].set_title("Weight (lbs)")
axs[0, 2].set_xlabel("Index")
axs[0, 2].set_ylabel("Weight (lbs)")
axs[0, 2].legend()

axs[0, 3].scatter(
    np.where(av_mask == 0)[0],
    df_non_av["Length"],
    color="gray",
    label="Non-AV",
)
axs[0, 3].scatter(
    np.where(av_mask == 1)[0],
    df_av["Length"],
    color="red",
    label="AV",
)
axs[0, 3].set_title("Length")
axs[0, 3].set_xlabel("Index")
axs[0, 3].set_ylabel("Length")
axs[0, 3].legend()

axs[0, 4].scatter(
    np.where(av_mask == 0)[0], df_non_av["Width"], color="gray", label="Non-AV"
)
axs[0, 4].scatter(np.where(av_mask == 1)[0], df_av["Width"], color="red", label="AV")
axs[0, 4].set_title("Width")
axs[0, 4].set_xlabel("Index")
axs[0, 4].set_ylabel("Width")
axs[0, 4].legend()

axs[1, 0].scatter(
    np.where(av_mask == 0)[0],
    df_non_av["Height"],
    color="gray",
    label="Non-AV",
)
axs[1, 0].scatter(
    np.where(av_mask == 1)[0],
    df_av["Height"],
    color="red",
    label="AV",
)
axs[1, 0].set_title("Height")
axs[1, 0].set_xlabel("Index")
axs[1, 0].set_ylabel("Height")
axs[1, 0].legend()

axs[1, 1].scatter(
    np.where(av_mask == 0)[0],
    df_non_av["% Weight distribution in front"],
    color="gray",
    label="Non-AV",
)
axs[1, 1].scatter(
    np.where(av_mask == 1)[0],
    df_av["% Weight distribution in front"],
    color="red",
    label="AV",
)
axs[1, 1].set_title("% Weight distribution in front")
axs[1, 1].set_xlabel("Index")
axs[1, 1].set_ylabel("% Weight distribution in front")
axs[1, 1].legend()

axs[1, 2].scatter(
    np.where(av_mask == 0)[0],
    df_non_av["Cylinders"],
    color="gray",
    label="Non-AV",
)
axs[1, 2].scatter(
    np.where(av_mask == 1)[0],
    df_av["Cylinders"],
    color="red",
    label="AV",
)
axs[1, 2].set_title("Cylinders")
axs[1, 2].set_xlabel("Index")
axs[1, 2].set_ylabel("Cylinders")
axs[1, 2].legend()

axs[1, 3].scatter(
    np.where(av_mask == 0)[0],
    df_non_av["Engine Displacement (L)"],
    color="gray",
    label="Non-AV",
)
axs[1, 3].scatter(
    np.where(av_mask == 1)[0],
    df_av["Engine Displacement (L)"],
    color="red",
    label="AV",
)
axs[1, 3].set_title("Engine Displacement (L)")
axs[1, 3].set_xlabel("Index")
axs[1, 3].set_ylabel("Engine Displacement (L)")
axs[1, 3].legend()

axs[1, 4].scatter(
    np.where(av_mask == 0)[0],
    df_non_av['Transmission Type ("1" for Auto and "0" for Manual)'],
    color="gray",
    label="Non-AV",
)
axs[1, 4].scatter(
    np.where(av_mask == 1)[0],
    df_av['Transmission Type ("1" for Auto and "0" for Manual)'],
    color="red",
    label="AV",
)
axs[1, 4].set_title("Transmission Type")
axs[1, 4].set_xlabel("Index")
axs[1, 4].set_ylabel("Transmission Type")
axs[1, 4].legend()


plt.tight_layout()
plt.show()

# %% [markdown]
# #### There are only 5 "AV" values in the Transmission Speeds column, a small fraction of the dataset. Plots show no distinct characteristics except a slight tendency to be newer models. Since the model will use the most common predictor values for weight ranges and "AV" cases are few, they will have negligible impact. Therefore, I will remove the rows containing "AV".
# * Convert Column to Numeric Datatype

# %%
df = df[df['Transmission (Speeds) Listed as S6 in the "TRANS" column'] != "AV"]
df['Transmission (Speeds) Listed as S6 in the "TRANS" column'] = df[
    'Transmission (Speeds) Listed as S6 in the "TRANS" column'
].astype("Int32")
df
# Out:
# C:\Users\Johannes\AppData\Local\Temp\ipykernel_37060\2055433649.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Transmission (Speeds) Listed as S6 in the "TRANS" column'] = df[
#      Team   Student Number Weight Range Year Range    Student Name  \
# 0        0               0    3500-4500  2009-2015          Prof A
# 1        1               1    1500-2000  1988-1992  Jack McCartney
# 2        1               1    1500-2000  1988-1992  Jack McCartney
# 3        1               1    1500-2000  1988-1992  Jack McCartney
# 4        1               1    1500-2000  1988-1992  Jack McCartney
# ..     ...             ...          ...        ...             ...
# 621     25               5    3500-4500  2009-2015      Alex Bloom
# 622     25               5    3500-4500  2009-2015      Alex Bloom
# 623     25               5    3500-4500  2009-2015      Alex Bloom
# 624     25               5    3500-4500  2009-2015      Alex Bloom
# 625     25               5    3500-4500  2009-2015      Alex Bloom
#
#                   Car Name  Model Year  Combined HWY and City MPG  \
# 0            The Batmobile      2012.0                       60.0
# 1         Mazda Miata MX-5      1992.0                       23.0
# 2      Chyrsler New Yorker      1992.0                       19.0
# 3      Ford Crown Victoria      1992.0                       20.0
# 4         Cadillac Seville      1992.0                       18.0
# ..                     ...         ...                        ...
# 621           Ford Mustang      2010.0                       19.0
# 622    Audi Q5 5DR SUV 2.0      2012.0                       22.0
# 623  Maserati Quattroporte      2012.0                       15.0
# 624  Mercedez-Benz CLS 550      2009.0                       23.0
# 625      Toyota FJ Cruiser      2009.0                       26.0
#
#      Weight (lbs)  % Weight distribution in front      Length      Width  \
# 0     4000.000000                            59.0  191.729996  70.470001
# 1     2121.000000                            53.0  155.509995  66.139999
# 2     3337.000000                            63.0  193.699997  68.900002
# 3     3738.000000                            56.0  212.600006  77.949997
# 4     3557.000000                            63.0  204.330002  74.410004
# ..            ...                             ...         ...        ...
# 621   3750.000000                            53.0  188.190002  74.019997
# 622   4089.570068                            53.0  182.279999  74.800003
# 623   4376.500000                            47.0  198.199997  74.410004
# 624   3982.000000                            52.0  193.699997  73.620003
# 625   4286.000000                            53.0  177.169998  75.199997
#
#         Height  Cylinders  Engine Displacement (L)  \
# 0    57.090000        8.0                      2.4
# 1    48.029999        4.0                      1.6
# 2    53.540001        6.0                      3.3
# 3    56.689999        8.0                      4.6
# 4    53.939999        8.0                      4.9
# ..         ...        ...                      ...
# 621  55.910000        8.0                      4.6
# 622  65.349998        4.0                      2.0
# 623  56.689999        8.0                      4.7
# 624  54.720001        8.0                      5.5
# 625  72.050003        4.0                      2.0
#
#      Transmission Type ("1" for Auto and "0" for Manual)  \
# 0                                                  1.0
# 1                                                  0.0
# 2                                                  1.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 621                                                1.0
# 622                                                1.0
# 623                                                1.0
# 624                                                1.0
# 625                                                1.0
#
#      Transmission (Speeds) Listed as S6 in the "TRANS" column
# 0                                                   15
# 1                                                    5
# 2                                                    4
# 3                                                    4
# 4                                                    4
# ..                                                 ...
# 621                                                  5
# 622                                                  8
# 623                                                  6
# 624                                                  6
# 625                                                  5
#
# [507 rows x 17 columns]

# %% [markdown]
# #### Three are a few rows which have significantly less data than the other rows (more than 25% of data missing). These Rows get removed from the dataset.

# %%
plt.barh(
    np.arange(20), df.isnull().mean(axis=1).sort_values(ascending=False).head(20) * 100
)
plt.axvline(25, color="red", linestyle="--")

plt.title("Percentage of Missing Values in Rows (Top 20)")
plt.xlabel("Missing Values (%)")
plt.ylabel("Row-Index")
plt.yticks(
    np.arange(20), df.isnull().mean(axis=1).sort_values(ascending=False).head(20).index
)
plt.gca().invert_yaxis()

# %%
df = df.drop([456, 457, 458, 459, 460, 365, 361, 362, 363, 364], axis=0)
df
# Out:
#      Team   Student Number Weight Range Year Range    Student Name  \
# 0        0               0    3500-4500  2009-2015          Prof A
# 1        1               1    1500-2000  1988-1992  Jack McCartney
# 2        1               1    1500-2000  1988-1992  Jack McCartney
# 3        1               1    1500-2000  1988-1992  Jack McCartney
# 4        1               1    1500-2000  1988-1992  Jack McCartney
# ..     ...             ...          ...        ...             ...
# 621     25               5    3500-4500  2009-2015      Alex Bloom
# 622     25               5    3500-4500  2009-2015      Alex Bloom
# 623     25               5    3500-4500  2009-2015      Alex Bloom
# 624     25               5    3500-4500  2009-2015      Alex Bloom
# 625     25               5    3500-4500  2009-2015      Alex Bloom
#
#                   Car Name  Model Year  Combined HWY and City MPG  \
# 0            The Batmobile      2012.0                       60.0
# 1         Mazda Miata MX-5      1992.0                       23.0
# 2      Chyrsler New Yorker      1992.0                       19.0
# 3      Ford Crown Victoria      1992.0                       20.0
# 4         Cadillac Seville      1992.0                       18.0
# ..                     ...         ...                        ...
# 621           Ford Mustang      2010.0                       19.0
# 622    Audi Q5 5DR SUV 2.0      2012.0                       22.0
# 623  Maserati Quattroporte      2012.0                       15.0
# 624  Mercedez-Benz CLS 550      2009.0                       23.0
# 625      Toyota FJ Cruiser      2009.0                       26.0
#
#      Weight (lbs)  % Weight distribution in front      Length      Width  \
# 0     4000.000000                            59.0  191.729996  70.470001
# 1     2121.000000                            53.0  155.509995  66.139999
# 2     3337.000000                            63.0  193.699997  68.900002
# 3     3738.000000                            56.0  212.600006  77.949997
# 4     3557.000000                            63.0  204.330002  74.410004
# ..            ...                             ...         ...        ...
# 621   3750.000000                            53.0  188.190002  74.019997
# 622   4089.570068                            53.0  182.279999  74.800003
# 623   4376.500000                            47.0  198.199997  74.410004
# 624   3982.000000                            52.0  193.699997  73.620003
# 625   4286.000000                            53.0  177.169998  75.199997
#
#         Height  Cylinders  Engine Displacement (L)  \
# 0    57.090000        8.0                      2.4
# 1    48.029999        4.0                      1.6
# 2    53.540001        6.0                      3.3
# 3    56.689999        8.0                      4.6
# 4    53.939999        8.0                      4.9
# ..         ...        ...                      ...
# 621  55.910000        8.0                      4.6
# 622  65.349998        4.0                      2.0
# 623  56.689999        8.0                      4.7
# 624  54.720001        8.0                      5.5
# 625  72.050003        4.0                      2.0
#
#      Transmission Type ("1" for Auto and "0" for Manual)  \
# 0                                                  1.0
# 1                                                  0.0
# 2                                                  1.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 621                                                1.0
# 622                                                1.0
# 623                                                1.0
# 624                                                1.0
# 625                                                1.0
#
#      Transmission (Speeds) Listed as S6 in the "TRANS" column
# 0                                                   15
# 1                                                    5
# 2                                                    4
# 3                                                    4
# 4                                                    4
# ..                                                 ...
# 621                                                  5
# 622                                                  8
# 623                                                  6
# 624                                                  6
# 625                                                  5
#
# [497 rows x 17 columns]

# %% [markdown]
# #### Drop rows where MVG (value to be predicted later on) is missing

# %%
df = df.dropna(axis=0, subset=["Combined HWY and City MPG"])
df
# Out:
#      Team   Student Number Weight Range Year Range    Student Name  \
# 0        0               0    3500-4500  2009-2015          Prof A
# 1        1               1    1500-2000  1988-1992  Jack McCartney
# 2        1               1    1500-2000  1988-1992  Jack McCartney
# 3        1               1    1500-2000  1988-1992  Jack McCartney
# 4        1               1    1500-2000  1988-1992  Jack McCartney
# ..     ...             ...          ...        ...             ...
# 621     25               5    3500-4500  2009-2015      Alex Bloom
# 622     25               5    3500-4500  2009-2015      Alex Bloom
# 623     25               5    3500-4500  2009-2015      Alex Bloom
# 624     25               5    3500-4500  2009-2015      Alex Bloom
# 625     25               5    3500-4500  2009-2015      Alex Bloom
#
#                   Car Name  Model Year  Combined HWY and City MPG  \
# 0            The Batmobile      2012.0                       60.0
# 1         Mazda Miata MX-5      1992.0                       23.0
# 2      Chyrsler New Yorker      1992.0                       19.0
# 3      Ford Crown Victoria      1992.0                       20.0
# 4         Cadillac Seville      1992.0                       18.0
# ..                     ...         ...                        ...
# 621           Ford Mustang      2010.0                       19.0
# 622    Audi Q5 5DR SUV 2.0      2012.0                       22.0
# 623  Maserati Quattroporte      2012.0                       15.0
# 624  Mercedez-Benz CLS 550      2009.0                       23.0
# 625      Toyota FJ Cruiser      2009.0                       26.0
#
#      Weight (lbs)  % Weight distribution in front      Length      Width  \
# 0     4000.000000                            59.0  191.729996  70.470001
# 1     2121.000000                            53.0  155.509995  66.139999
# 2     3337.000000                            63.0  193.699997  68.900002
# 3     3738.000000                            56.0  212.600006  77.949997
# 4     3557.000000                            63.0  204.330002  74.410004
# ..            ...                             ...         ...        ...
# 621   3750.000000                            53.0  188.190002  74.019997
# 622   4089.570068                            53.0  182.279999  74.800003
# 623   4376.500000                            47.0  198.199997  74.410004
# 624   3982.000000                            52.0  193.699997  73.620003
# 625   4286.000000                            53.0  177.169998  75.199997
#
#         Height  Cylinders  Engine Displacement (L)  \
# 0    57.090000        8.0                      2.4
# 1    48.029999        4.0                      1.6
# 2    53.540001        6.0                      3.3
# 3    56.689999        8.0                      4.6
# 4    53.939999        8.0                      4.9
# ..         ...        ...                      ...
# 621  55.910000        8.0                      4.6
# 622  65.349998        4.0                      2.0
# 623  56.689999        8.0                      4.7
# 624  54.720001        8.0                      5.5
# 625  72.050003        4.0                      2.0
#
#      Transmission Type ("1" for Auto and "0" for Manual)  \
# 0                                                  1.0
# 1                                                  0.0
# 2                                                  1.0
# 3                                                  1.0
# 4                                                  1.0
# ..                                                 ...
# 621                                                1.0
# 622                                                1.0
# 623                                                1.0
# 624                                                1.0
# 625                                                1.0
#
#      Transmission (Speeds) Listed as S6 in the "TRANS" column
# 0                                                   15
# 1                                                    5
# 2                                                    4
# 3                                                    4
# 4                                                    4
# ..                                                 ...
# 621                                                  5
# 622                                                  8
# 623                                                  6
# 624                                                  6
# 625                                                  5
#
# [495 rows x 17 columns]

# %% [markdown]
# # Rename Columns

# %%
df = df.rename(
    columns={
        "Team ": "Team",
        "Combined HWY and City MPG": "MPG",
        "% Weight distribution in front": "Weight Distribution (%)",
        "Length": "Length (in)",
        "Width": "Width (in)",
        "Height": "Height (in)",
        'Transmission Type ("1" for Auto and "0" for Manual)': "Transmission Type",
        'Transmission (Speeds) Listed as S6 in the "TRANS" column': "Transmission Speeds",
    }
)
df
# Out:
#      Team  Student Number Weight Range Year Range    Student Name  \
# 0       0               0    3500-4500  2009-2015          Prof A
# 1       1               1    1500-2000  1988-1992  Jack McCartney
# 2       1               1    1500-2000  1988-1992  Jack McCartney
# 3       1               1    1500-2000  1988-1992  Jack McCartney
# 4       1               1    1500-2000  1988-1992  Jack McCartney
# ..    ...             ...          ...        ...             ...
# 621    25               5    3500-4500  2009-2015      Alex Bloom
# 622    25               5    3500-4500  2009-2015      Alex Bloom
# 623    25               5    3500-4500  2009-2015      Alex Bloom
# 624    25               5    3500-4500  2009-2015      Alex Bloom
# 625    25               5    3500-4500  2009-2015      Alex Bloom
#
#                   Car Name  Model Year   MPG  Weight (lbs)  \
# 0            The Batmobile      2012.0  60.0   4000.000000
# 1         Mazda Miata MX-5      1992.0  23.0   2121.000000
# 2      Chyrsler New Yorker      1992.0  19.0   3337.000000
# 3      Ford Crown Victoria      1992.0  20.0   3738.000000
# 4         Cadillac Seville      1992.0  18.0   3557.000000
# ..                     ...         ...   ...           ...
# 621           Ford Mustang      2010.0  19.0   3750.000000
# 622    Audi Q5 5DR SUV 2.0      2012.0  22.0   4089.570068
# 623  Maserati Quattroporte      2012.0  15.0   4376.500000
# 624  Mercedez-Benz CLS 550      2009.0  23.0   3982.000000
# 625      Toyota FJ Cruiser      2009.0  26.0   4286.000000
#
#      Weight Distribution (%)  Length (in)  Width (in)  Height (in)  Cylinders  \
# 0                       59.0   191.729996   70.470001    57.090000        8.0
# 1                       53.0   155.509995   66.139999    48.029999        4.0
# 2                       63.0   193.699997   68.900002    53.540001        6.0
# 3                       56.0   212.600006   77.949997    56.689999        8.0
# 4                       63.0   204.330002   74.410004    53.939999        8.0
# ..                       ...          ...         ...          ...        ...
# 621                     53.0   188.190002   74.019997    55.910000        8.0
# 622                     53.0   182.279999   74.800003    65.349998        4.0
# 623                     47.0   198.199997   74.410004    56.689999        8.0
# 624                     52.0   193.699997   73.620003    54.720001        8.0
# 625                     53.0   177.169998   75.199997    72.050003        4.0
#
#      Engine Displacement (L)  Transmission Type  Transmission Speeds
# 0                        2.4                1.0                   15
# 1                        1.6                0.0                    5
# 2                        3.3                1.0                    4
# 3                        4.6                1.0                    4
# 4                        4.9                1.0                    4
# ..                       ...                ...                  ...
# 621                      4.6                1.0                    5
# 622                      2.0                1.0                    8
# 623                      4.7                1.0                    6
# 624                      5.5                1.0                    6
# 625                      2.0                1.0                    5
#
# [495 rows x 17 columns]

# %% [markdown]
# # Year / Weight Investigation
# ### Little bit weird that Weight Range and the Weight (lbs) don't align (same for Year Range and Model Year)

# %%
matching_years, not_matching_years = [], []
matching_weights, not_matching_weights = [], []

for idx, row in df.iterrows():
    year_from, year_to = (
        int(row["Year Range"].split("-")[0]),
        int(row["Year Range"].split("-")[1]),
    )
    weight_from, weight_to = (
        int(row["Weight Range"].split("-")[0]),
        int(row["Weight Range"].split("-")[1]),
    )

    if year_from <= row["Model Year"] <= year_to:
        matching_years.append(idx)
    else:
        not_matching_years.append(idx)

    if weight_from <= row["Weight (lbs)"] <= weight_to:
        matching_weights.append(idx)
    else:
        not_matching_weights.append(idx)

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(8, 4))

axs[0].bar(
    ["Matching Years", "Not Matching Years"],
    [len(matching_years), len(not_matching_years)],
    color=["green", "red"],
)
axs[0].set_title("Matching Years vs Not Matching Years")
axs[0].set_ylabel("Count")
axs[0].set_ylim(0, len(df))

axs[1].bar(
    ["Matching Weights", "Not Matching Weights"],
    [len(matching_weights), len(not_matching_weights)],
    color=["green", "red"],
)
axs[1].set_title("Matching Weights vs Not Matching Weights")
axs[1].set_ylabel("Count")
axs[1].set_ylim(0, len(df))

plt.tight_layout()
plt.show()

# %%
df_team_sort = df.sort_values(by=["Team", "Student Number"])
df_student_sort = df.sort_values(by=["Student Number", "Team"])

# %%
cmap = plt.get_cmap("tab20")
n_colors = cmap.N

ctr = 0
year_idx_ranges, year_ranges, year_colors = [], [], []
for i, team in enumerate(df_team_sort["Team"].unique()):
    df_temp = df_team_sort[df_team_sort["Team"] == team]
    year_idx_ranges.append((ctr, ctr + len(df_temp) - 1))
    year_ranges.append(
        (
            int(df_temp.iloc[0]["Year Range"].split("-")[0]),
            int(df_temp.iloc[0]["Year Range"].split("-")[1]),
        )
    )
    year_colors.extend([cmap(i % n_colors)] * len(df_temp))
    ctr += len(df_temp)

fix, axs = plt.subplots(nrows=1, ncols=2, figsize=(16, 6))

axs[0].scatter(np.arange(len(df)), df_team_sort["Model Year"], c=year_colors)
for i, ((idx_from, idx_to), (year_from, year_to)) in enumerate(
    zip(year_idx_ranges, year_ranges)
):
    if i == 0:
        axs[0].hlines(
            year_from, idx_from, idx_to, colors="black", linewidth=2, label="Year Range"
        )
    else:
        axs[0].hlines(year_from, idx_from, idx_to, colors="black", linewidth=2)

    axs[0].hlines(year_to, idx_from, idx_to, colors="black", linewidth=2)

axs[0].set_title("Model Year by Team")
axs[0].set_xlabel("Index (Sorted by Team)")
axs[0].set_ylabel("Model Year")
axs[0].legend()

axs[1].hist(df["Model Year"], bins=10, edgecolor="black")
axs[1].set_title("Distribution of Model Year")
axs[1].set_xlabel("Model Year")
axs[1].set_ylabel("Frequency")

plt.tight_layout()
plt.show()

# %%
cmap = plt.get_cmap("tab20")
n_colors = cmap.N

ctr = 0
weight_idx_ranges, weight_ranges, weight_colors = [], [], []
for i, student in enumerate(df_student_sort["Student Number"].unique()):
    df_temp = df_student_sort[df_student_sort["Student Number"] == student]
    weight_idx_ranges.append((ctr, ctr + len(df_temp) - 1))
    weight_ranges.append(
        (
            int(df_temp.iloc[0]["Weight Range"].split("-")[0]),
            int(df_temp.iloc[0]["Weight Range"].split("-")[1]),
        )
    )
    weight_colors.extend([cmap(i % n_colors)] * len(df_temp))
    ctr += len(df_temp)

fix, axs = plt.subplots(nrows=1, ncols=2, figsize=(16, 6))

axs[0].scatter(np.arange(len(df)), df_student_sort["Weight (lbs)"], c=weight_colors)
for i, ((idx_from, idx_to), (weight_from, weight_to)) in enumerate(
    zip(weight_idx_ranges, weight_ranges)
):
    if i == 0:
        axs[0].hlines(
            weight_from,
            idx_from,
            idx_to,
            colors="black",
            linewidth=2,
            label="Weight Range",
        )
    else:
        axs[0].hlines(weight_from, idx_from, idx_to, colors="black", linewidth=2)

    axs[0].hlines(weight_to, idx_from, idx_to, colors="black", linewidth=2)

axs[0].set_title("Model Weight by Student Number")
axs[0].set_xlabel("Index (Sorted by Student)")
axs[0].set_ylabel("Weight (lbs)")
axs[0].legend()

axs[1].hist(df["Weight (lbs)"], bins=10, edgecolor="black")
axs[1].set_title("Distribution of Weight (lbs)")
axs[1].set_xlabel("Weight (lbs)")
axs[1].set_ylabel("Frequency")

plt.show()

# %% [markdown]
# ### Assumption: Each Team was assigned a Year Range to filter for cars and each Student within a team was assigned a Weight Range to search for cars, so the dataset contains roughly evenly distributed cars across different Model Years and Weights. Therefore Weight Range and Year Range was only important for gathering the data and for further analysis Model Year and Weight (lbs) can be used and the Year Range and Weight Range can be removed.
# * Remove Weight Range and Year Range Columns

# %%
df = df.drop(columns=["Year Range", "Weight Range"])
df
# Out:
#      Team  Student Number    Student Name               Car Name  Model Year  \
# 0       0               0          Prof A          The Batmobile      2012.0
# 1       1               1  Jack McCartney       Mazda Miata MX-5      1992.0
# 2       1               1  Jack McCartney    Chyrsler New Yorker      1992.0
# 3       1               1  Jack McCartney    Ford Crown Victoria      1992.0
# 4       1               1  Jack McCartney       Cadillac Seville      1992.0
# ..    ...             ...             ...                    ...         ...
# 621    25               5      Alex Bloom           Ford Mustang      2010.0
# 622    25               5      Alex Bloom    Audi Q5 5DR SUV 2.0      2012.0
# 623    25               5      Alex Bloom  Maserati Quattroporte      2012.0
# 624    25               5      Alex Bloom  Mercedez-Benz CLS 550      2009.0
# 625    25               5      Alex Bloom      Toyota FJ Cruiser      2009.0
#
#       MPG  Weight (lbs)  Weight Distribution (%)  Length (in)  Width (in)  \
# 0    60.0   4000.000000                     59.0   191.729996   70.470001
# 1    23.0   2121.000000                     53.0   155.509995   66.139999
# 2    19.0   3337.000000                     63.0   193.699997   68.900002
# 3    20.0   3738.000000                     56.0   212.600006   77.949997
# 4    18.0   3557.000000                     63.0   204.330002   74.410004
# ..    ...           ...                      ...          ...         ...
# 621  19.0   3750.000000                     53.0   188.190002   74.019997
# 622  22.0   4089.570068                     53.0   182.279999   74.800003
# 623  15.0   4376.500000                     47.0   198.199997   74.410004
# 624  23.0   3982.000000                     52.0   193.699997   73.620003
# 625  26.0   4286.000000                     53.0   177.169998   75.199997
#
#      Height (in)  Cylinders  Engine Displacement (L)  Transmission Type  \
# 0      57.090000        8.0                      2.4                1.0
# 1      48.029999        4.0                      1.6                0.0
# 2      53.540001        6.0                      3.3                1.0
# 3      56.689999        8.0                      4.6                1.0
# 4      53.939999        8.0                      4.9                1.0
# ..           ...        ...                      ...                ...
# 621    55.910000        8.0                      4.6                1.0
# 622    65.349998        4.0                      2.0                1.0
# 623    56.689999        8.0                      4.7                1.0
# 624    54.720001        8.0                      5.5                1.0
# 625    72.050003        4.0                      2.0                1.0
#
#      Transmission Speeds
# 0                     15
# 1                      5
# 2                      4
# 3                      4
# 4                      4
# ..                   ...
# 621                    5
# 622                    8
# 623                    6
# 624                    6
# 625                    5
#
# [495 rows x 15 columns]

# %%
df.to_csv("cleaned-data.csv", index=True)
